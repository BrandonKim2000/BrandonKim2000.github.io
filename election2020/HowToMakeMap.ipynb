# %%
# !pip install --upgrade plotly
# !pip install --upgrade geopandas
# !pip install --upgrade pyshp
# !pip install --upgrade shapely
# Out:
# Collecting plotly
#   Downloading plotly-4.14.1-py2.py3-none-any.whl (13.2 MB)
#      |████████████████████████████████| 13.2 MB 11.4 MB/s eta 0:00:01   |███████▏                        | 2.9 MB 3.3 MB/s eta 0:00:04
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied, skipping upgrade: six in /opt/conda/lib/python3.8/site-packages (from plotly) (1.15.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=6ae7239bc5ef3216b0e7da5a9f1d394a470d2987555adb4c01c094b0acd7396a
#   Stored in directory: /home/jovyan/.cache/pip/wheels/c4/a7/48/0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# Installing collected packages: retrying, plotly
# Successfully installed plotly-4.14.1 retrying-1.3.3
# Collecting geopandas
#   Downloading geopandas-0.8.1-py2.py3-none-any.whl (962 kB)
#      |████████████████████████████████| 962 kB 2.9 MB/s eta 0:00:01
# Collecting fiona
#   Downloading Fiona-1.8.18-cp38-cp38-manylinux1_x86_64.whl (14.7 MB)
#      |████████████████████████████████| 14.7 MB 11.7 MB/s eta 0:00:01   |█▏                              | 522 kB 5.4 MB/s eta 0:00:03
# Collecting shapely
#   Downloading Shapely-1.7.1-cp38-cp38-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 7.2 MB/s eta 0:00:01     |██                              | 61 kB 10.8 MB/s eta 0:00:01
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.0.0.post1-cp38-cp38-manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 5.6 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pandas>=0.23.0 in /opt/conda/lib/python3.8/site-packages (from geopandas) (1.1.1)
# Requirement already satisfied, skipping upgrade: six>=1.7 in /opt/conda/lib/python3.8/site-packages (from fiona->geopandas) (1.15.0)
# Requirement already satisfied, skipping upgrade: click<8,>=4.0 in /opt/conda/lib/python3.8/site-packages (from fiona->geopandas) (7.1.2)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.1-py3-none-any.whl (7.1 kB)
# Requirement already satisfied, skipping upgrade: attrs>=17 in /opt/conda/lib/python3.8/site-packages (from fiona->geopandas) (20.1.0)
# Requirement already satisfied, skipping upgrade: certifi in /opt/conda/lib/python3.8/site-packages (from fiona->geopandas) (2020.6.20)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.4 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.23.0->geopandas) (1.19.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.23.0->geopandas) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Installing collected packages: munch, click-plugins, cligj, fiona, shapely, pyproj, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.1 fiona-1.8.18 geopandas-0.8.1 munch-2.5.0 pyproj-3.0.0.post1 shapely-1.7.1
# Collecting pyshp
#   Downloading pyshp-2.1.2.tar.gz (217 kB)
#      |████████████████████████████████| 217 kB 2.6 MB/s eta 0:00:01
# Building wheels for collected packages: pyshp
#   Building wheel for pyshp (setup.py) ... done
#   Created wheel for pyshp: filename=pyshp-2.1.2-py3-none-any.whl size=36216 sha256=997dc3df6b94acdc9bf415b3916fb18408418892ee79e19e6991dc7a3100ace5
#   Stored in directory: /home/jovyan/.cache/pip/wheels/49/29/69/6b6a800e28c596146549d22f4e1013abfcbb466cd179e586d3
# Successfully built pyshp
# Installing collected packages: pyshp
# Successfully installed pyshp-2.1.2
# Requirement already up-to-date: shapely in /opt/conda/lib/python3.8/site-packages (1.7.1)

# %%
# !pip install plotly-geo
# Out:
# Collecting plotly-geo
#   Downloading plotly_geo-1.0.0-py3-none-any.whl (23.7 MB)
#      |████████████████████████████████| 23.7 MB 222 kB/s  eta 0:00:01   |████████████▉                   | 9.5 MB 2.2 MB/s eta 0:00:07
# Installing collected packages: plotly-geo
# Successfully installed plotly-geo-1.0.0

# %%
# !pip3 install plotly
# Out:
# Requirement already satisfied: plotly in /opt/conda/lib/python3.8/site-packages (4.14.1)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/lib/python3.8/site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from plotly) (1.15.0)

# %%
import plotly.figure_factory as ff
import numpy as np
import pandas as pd

df_sample = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/minoritymajority.csv')
df_sample_r = df_sample[df_sample['STNAME'] == 'Arizona']

values = df_sample_r['TOT_POP'].tolist()
fips = df_sample_r['FIPS'].tolist()

endpts = list(np.mgrid[min(values):max(values):4j])
colorscale = ["#030512","#1d1d3b","#323268","#3d4b94","#3e6ab0",
              "#4989bc","#60a7c7","#85c5d3","#b7e0e4","#eafcfd"]
fig = ff.create_choropleth(
    fips=fips, values=values, scope=['Arizona'], show_state_data=True,
    colorscale=colorscale, binning_endpoints=endpts, round_legend_values=True,
    plot_bgcolor='rgb(229,229,229)',
    paper_bgcolor='rgb(229,229,229)',
    legend_title='Population by County',
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5},
    exponent_format=True,
)
fig.layout.template = None
fig.show()
# Out:
# <div>                            <div id="aab4dca8-66b5-4a35-a56c-a62c2b6fca21" class="plotly-graph-div" style="height:450px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("